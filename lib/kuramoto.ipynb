# %%
# %run kuramoto.py --dt 2e-3 --N 20000 --steps 12000 --periods 1. --K 5.0 --precision 1e-18 --a .25 --d .5 --b 10.

# %%
# %run kuramoto.py --dt 2e-3 --N 35000 --steps 10000 --periods 1. --K 5.0 --precision 1e-18 --a .25 --d .5 --b 10.
# Out:
# c = 1.0, N = 27211
#  N = 27211
# |E| = 79762
# E[omega] = -0.000, Var[omega] = 1.002
# compute time (jax DP): 127.202 (sec)

# %%
# %run kuramoto.py --dt 2e-3 --N 20000 --steps 12000 --periods 1. --K 5.0 --precision 1e-18 --a .25 --d .125 --b 100.
# Out:
# c = 1.0, N = 15562
#  N = 15562
# |E| = 61394
# E[omega] = -0.000, Var[omega] = 1.000
# compute time (jax DP): 88.374 (sec)

# %%
# %run kuramoto.py --dt 2e-3 --N 20000 --steps 12000 --periods 1. --K 1.7 --precision 1e-18 --a 1. --plot True
# Out:
# c = 1.0, N = 15562
#  N = 15562
# |E| = 61394
# E[omega] = -0.000, Var[omega] = 1.000
# compute time (jax DP): 86.885 (sec)
#  R = 0.036329214845913525 ± 0.015939480133805844
#  Rc/R = 3.6745055635722954

# %%
# %run kuramoto.py --dt 2e-3 --N 20000 --steps 12000 --periods 1. --K 3.4 --precision 1e-18 --a 1. --plot True
# Out:
# c = 1.0, N = 15774
#  N = 15774
# |E| = 50278
# E[omega] = -0.000, Var[omega] = 1.000
# compute time (jax DP): 81.971 (sec)
#  R = 0.16726819297830106 ± 0.04686693625727005
#  Rc/R = 1.1039707971110377

# %%
for i in range(5): n=10**i; print((n-1)*n//2)
# Out:
# 0
# 45
# 4950
# 499500
# 49995000

# %%
def chunker(i, j, size=10000):
    idx = np.zeros((2,size))
    k = 0
    j+=1
    while k < size:
        idx[:,k] = i,j
        i += int(j==(n-1))
        j = (j+1)//n
    return idx, (i,j)

# %%
chunker(0,0,size=10)
